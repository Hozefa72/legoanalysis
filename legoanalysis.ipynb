# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
lego=pd.read_csv("lego_sets.csv")
lego
# Out:
#       set_num                        name  year  num_parts    theme_name  \
# 0        00-1             Weetabix Castle  1970      471.0        Castle
# 1      0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2      0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3      0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4      0013-1          Space Mini-Figures  1979       12.0  Supplemental
# ...       ...                         ...   ...        ...           ...
# 11981     NaN                         NaN  2014        NaN           NaN
# 11982     NaN                         NaN  2006        NaN           NaN
# 11983     NaN                         NaN  2017        NaN           NaN
# 11984     NaN                         NaN  2017        8.0           NaN
# 11985     NaN                         NaN  2003        NaN           NaN
#
#        parent_theme
# 0          Legoland
# 1              Town
# 2            Castle
# ...

# %%
theme=pd.read_csv("parent_themes.csv")
theme
# Out:
#       id          name  is_licensed
# 0      1       Technic        False
# 1     22       Creator        False
# 2     50          Town        False
# 3    112        Racers        False
# 4    126         Space        False
# ..   ...           ...          ...
# 106  605  Nexo Knights        False
# 107  606   Angry Birds         True
# 108  607  Ghostbusters         True
# 109  608        Disney         True
# 110  610    Brickheadz        False
#
# [111 rows x 3 columns]

# %%
df=lego.merge(theme,left_on='parent_theme',right_on='name')

# %%
df.drop(columns=['name_y'],inplace=True)

# %%
df=df[df['is_licensed']==True]

# %%
a=df[df['parent_theme']=='Star Wars']

# %%
df[df['set_num'].isna()]
# Out:
#       set_num name_x  year  num_parts theme_name  parent_theme   id  \
# 5827      NaN    NaN  2017      304.0        NaN  Super Heroes  482
# 5828      NaN    NaN  2017      196.0        NaN  Super Heroes  482
# 5829      NaN    NaN  2014        NaN        NaN  Super Heroes  482
# 5830      NaN    NaN  2013       16.0        NaN  Super Heroes  482
# 5831      NaN    NaN  2013        NaN        NaN  Super Heroes  482
# ...       ...    ...   ...        ...        ...           ...  ...
# 10274     NaN    NaN  2015      518.0        NaN     Minecraft  577
# 10275     NaN    NaN  2016        NaN        NaN     Minecraft  577
# 10276     NaN    NaN  2017      502.0        NaN     Minecraft  577
# 10277     NaN    NaN  2014        NaN        NaN     Minecraft  577
# 10278     NaN    NaN  2017        NaN        NaN     Minecraft  577
#
#        is_licensed
# 5827          True
# 5828          True
# 5829          True
# 5830          True
# 5831          True
# ...            ...
# ...

# %%
df=df.dropna(subset=['set_num'])
df
# Out:
#        set_num                         name_x  year  num_parts  \
# 3493   10018-1                     Darth Maul  2001     1868.0
# 3494   10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495   10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496   10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497   10123-1                     Cloud City  2003      707.0
# ...        ...                            ...   ...        ...
# 11981   8410-1                      Swampfire  2010       22.0
# 11982   8411-1                    ChromaStone  2010       21.0
# 11983   8517-1                   Humungousaur  2010       14.0
# 11984   8518-1                        Jet Ray  2010        NaN
# 11985   8519-1                      Big Chill  2010       20.0
#
#                     theme_name parent_theme   id  is_licensed
# 3493                 Star Wars    Star Wars  158         True
# 3494   Star Wars Episode 4/5/6    Star Wars  158         True
# ...

# %%
int((a.shape[0]/df.shape[0])*100)
# Out:
# 51

# %%
df
# Out:
#          set_num            name_x  year  num_parts               theme_name  \
# 3702      7161-1        Gungan Sub  1999      379.0      Star Wars Episode 1
# 3705      7171-1  Mos Espa Podrace  1999        NaN      Star Wars Episode 1
# 3690      7140-1    X-wing Fighter  1999      271.0  Star Wars Episode 4/5/6
# 3685      7130-1       Snowspeeder  1999        NaN  Star Wars Episode 4/5/6
# 3684      7128-1     Speeder Bikes  1999       93.0  Star Wars Episode 4/5/6
# ...          ...               ...   ...        ...                      ...
# 5692    71017-17    March Harriet™  2017        6.0                   Batman
# 5691    71017-16           Catman™  2017        NaN                   Batman
# 5690    71017-15    Zodiac Master™  2017        6.0                   Batman
# 5696    71017-20         The Mime™  2017        NaN                   Batman
# 4082  SW911725-1       Sandcrawler  2017        NaN                Star Wars
#
#       parent_theme   id  is_licensed
# ...

# %%
a.groupby('year')['num_parts'].count()
# Out:
# year
# 1999     7
# 2000    16
# 2001     9
# 2002    16
# 2003    16
# 2004    11
# 2005    18
# 2006     5
# 2007    12
# 2008    15
# 2009    18
# 2010    21
# 2011    15
# 2012    24
# 2013    19
# 2014    23
# 2015    34
# 2016    27
# 2017    28
# Name: num_parts, dtype: int64

# %%
df=df.sort_values('year')

# %%
a=df.groupby(['year','parent_theme']).sum().reset_index()
a
# Out:
#     year              parent_theme  \
# 0   1999                 Star Wars
# 1   2000     Disney's Mickey Mouse
# 2   2000                 Star Wars
# 3   2001              Harry Potter
# 4   2001                 Star Wars
# ..   ...                       ...
# 78  2017           Disney Princess
# 79  2017                 Minecraft
# 80  2017  Pirates of the Caribbean
# 81  2017                 Star Wars
# 82  2017              Super Heroes
#
#                                               set_num  \
# 0   7161-17111-17151-17101-17110-17131-17150-17141...
# 1                      4178-14165-14166-14167-14164-1
# 2   VP-118000-18001-18002-1swminifigs-1VP-127191-1...
# 3   4702-14721-14709-14701-14704-14706-14708-14705...
# 4   7127-17146-110018-17126-110019-1VP-27186-16502...
# ..                                                ...
# 78         41146-141143-141148-141147-141145-141144-1
# 79  21132-121133-121131-121134-121130-121129-12113...
# ...

# %%
a.sort_values('is_licensed',ascending=False).drop_duplicates(['year'])
# Out:
#     year  parent_theme                                            set_num  \
# 82  2017  Super Heroes  76071-1853651-176087-176072-176085-170905-1709...
# 76  2016     Star Wars  75116-175115-175117-175141-175138-175139-17514...
# 67  2015     Star Wars  75084-130275-130276-175082-175083-130274-17508...
# 59  2014     Star Wars  66495-1comcon039-166512-175031-166515-175024-1...
# 47  2012     Star Wars  9497-19496-19499-19500-19515-15001307-15001309...
# 32  2009     Star Wars  comcon007-12853590-130005-1comcon005-130006-16...
# 52  2013     Star Wars  75010-175011-175018-175012-175013-175014-17501...
# 9   2003     Star Wars  4489-14476-14475-14207901-13219-14490-14501-14...
# 42  2011     Star Wars  7868-17869-130054-17877-130053-130055-17914-12...
# 36  2010     Star Wars  8129-18128-1CELEBV-18098-18093-18096-18095-180...
# 16  2005     Star Wars  6965-2K7283-165844-1sw117promo-165771-1SWMP-11...
# 6   2002     Star Wars  7119-17143-14195641-17133-17139-17153-17142-1K...
# ...

# %%
a
# Out:
#     year              parent_theme  set_num  name_x  num_parts  theme_name  \
# 0   1999                 Star Wars       13      13          7          13
# 1   2000     Disney's Mickey Mouse        5       5          4           5
# 2   2000                 Star Wars       26      26         16          26
# 3   2001              Harry Potter       11      11          6          11
# 4   2001                 Star Wars       14      14          9          14
# ..   ...                       ...      ...     ...        ...         ...
# 78  2017           Disney Princess        6       6          1           6
# 79  2017                 Minecraft        9       9          5           9
# 80  2017  Pirates of the Caribbean        1       1          1           1
# 81  2017                 Star Wars       55      55         28          55
# 82  2017              Super Heroes       72      72         46          72
#
#     id  is_licensed
# 0   13           13
# 1    5            5
# ...
